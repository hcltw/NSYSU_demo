# %%
#載入特定程式庫
import numpy as np
import pandas as pd

# %%
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
data = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])

# %%
sum = X + data
print(sum)

# %%
url = 'https://raw.githubusercontent.com/hcltw/NSYSU_demo/main/test.csv'
df = pd.read_csv(url)
data_array = df.values
print(data_array[:5])
