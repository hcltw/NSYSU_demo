# %%
import pandas as pd
import numpy as np
import os
url = 'https://raw.githubusercontent.com/hcltw/NSYSU_demo/refs/heads/main/data/'

# %%
filepath  = os.path.join(url, "1.csv")
df = pd.read_csv(filepath, header=None)
arr = df.values

print(arr.shape)

# %%
big_array = []

for i in range(1, 16):              # 受試者編號從 x 從 1 到 15
    filename = f"{i}.csv"
    filepath = os.path.join(url, filename)
    df = pd.read_csv(filepath, header=None)  
    arr = df.values               # 轉成 numpy array
    big_array.append(arr)

# %%
#印出有幾個受試者
print(len(arrays))

# %%
#印出1號受試者的第一行數據
print(arrays[0][1])
